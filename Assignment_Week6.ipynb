# %% [markdown]
# [Bag of Words Meets Bags of Popcorn](https://www.kaggle.com/c/word2vec-nlp-tutorial/data)
# ======
#
# ## Data Set
#
# The labeled data set consists of 50,000 IMDB movie reviews, specially selected for sentiment analysis. The sentiment of reviews is binary, meaning the IMDB rating < 5 results in a sentiment score of 0, and rating >=7 have a sentiment score of 1. No individual movie has more than 30 reviews. The 25,000 review labeled training set does not include any of the same movies as the 25,000 review test set. In addition, there are another 50,000 IMDB reviews provided without any rating labels.
#
# ## File descriptions
#
# labeledTrainData - The labeled training set. The file is tab-delimited and has a header row followed by 25,000 rows containing an id, sentiment, and text for each review.
# ## Data fields
#
# * id - Unique ID of each review
# * sentiment - Sentiment of the review; 1 for positive reviews and 0 for negative reviews
# * review - Text of the review
#
# ## Objective
# Objective of this dataset is base on **review** we predict **sentiment** (positive or negative) so X is **review** column and y is **sentiment** column

# %% [markdown]
# ## 1. Load Dataset
# we only forcus on "labeledTrainData.csv" file
#
# Let's first of all have a look at the data.
#
# [Click here to download dataset](https://s3-ap-southeast-1.amazonaws.com/ml101-khanhnguyen/week3/assignment/labeledTrainData.tsv)

# %%
# Import pandas, numpy
import pandas as pd
import numpy as np

# %%
# Read dataset with extra params sep='\t', encoding="latin-1"
df = pd.read_csv('labeledTrainData.tsv', sep = '\t', encoding = 'latin-1')
df
# Out:
#             id  sentiment                                             review
# 0       5814_8          1  With all this stuff going down at the moment w...
# 1       2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2       7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3       3630_4          0  It must be assumed that those who praised this...
# 4       9495_8          1  Superbly trashy and wondrously unpretentious 8...
# 5       8196_8          1  I dont know why people think this is such a ba...
# 6       7166_2          0  This movie could have been very good, but come...
# 7      10633_1          0  I watched this video at a friend's house. I'm ...
# 8        319_1          0  A friend of mine bought this film for Â£1, and...
# 9      8713_10          1  <br /><br />This movie is full of references. ...
# 10      2486_3          0  What happens when an army of wetbacks, towelhe...
# 11     6811_10          1  Although I generally do not like remakes belie...
# 12     11744_9          1  \Mr. Harvey Lights a Candle\" is anchored by a...
# 13      7369_1          0  I had a feeling that after \Submerged\", this ...
# 14     12081_1          0  note to George Litman, and others: the Mystery...
# 15      3561_4          0  Stephen King adaptation (scripted by King hims...
# 16      4489_1          0  `The Matrix' was an exciting summer blockbuste...
# 17      3951_2          0  Ulli Lommel's 1980 film 'The Boogey Man' is no...
# 18     3304_10          1  This movie is one among the very few Indian mo...
# 19     9352_10          1  Most people, especially young people, may not ...
# 20      3374_7          1  \Soylent Green\" is one of the best and most d...
# 21     10782_7          1  Michael Stearns plays Mike, a sexually frustra...
# 22     5414_10          1  This happy-go-luck 1939 military swashbuckler,...
# 23     10492_1          0  I would love to have that two hours of my life...
# 24      3350_3          0  The script for this movie was probably found i...
# 25      6581_7          1  Looking for Quo Vadis at my local video store,...
# 26      2203_3          0  Note to all mad scientists everywhere: if you'...
# 27       689_1          0  What the ........... is this ? This must, with...
# 28      9152_1          0  Intrigued by the synopsis (every gay video the...
# 29      6077_1          0  Would anyone really watch this RUBBISH if it d...
# ...        ...        ...                                                ...
# 24970   9389_7          1  Red Rock West (1993)<br /><br />Nicolas Cage g...
# 24971   9251_9          1  what can i say?, ms Erika Eleniak is my favori...
# 24972  1422_10          1  The spoiler warning is for those people who wa...
# 24973   7415_2          0  What do you call a horror story without horror...
# 24974   7492_7          1  Though not a horror film in the traditional se...
# 24975  7689_10          1  This was what black society was like before th...
# 24976  12370_4          0  They probably should have called this movie Th...
# 24977   5625_8          1  Attractive Marjorie(Farrah Fawcett)lives in fe...
# 24978   9397_9          1  Vaguely reminiscent of great 1940's westerns, ...
# 24979   5992_7          1  I admit I had no idea what to expect before vi...
# 24980  2488_10          1  To me, the final scene, in which Harris respon...
# 24981  9627_10          1  This is by far the funniest short made by the ...
# 24982   3822_2          0  To be a Buster Keaton fan is to have your hear...
# 24983   5983_4          0  I was one of those \few Americans\" that grew ...
# 24984   8021_2          0  Visually disjointed and full of itself, the di...
# 24985   3471_3          0  this movie had more holes than a piece of swis...
# 24986  6034_10          1  Last November, I had a chance to see this film...
# 24987   1988_9          1  First off, I'd like to make a correction on an...
# 24988   7623_9          1  While originally reluctant to jump on the band...
# 24989   5974_7          1  I heard about this movie when watching VH1's \...
# 24990   2034_9          1  I've never been huge on IMAX films. They're co...
# 24991   9416_3          0  Steve McQueen has certainly a lot of loyal fan...
# 24992  10994_1          0  Sometimes you wonder how some people get fundi...
# 24993  10957_3          0  I am a student of film, and have been for seve...
# 24994   2372_1          0  Unimaginably stupid, redundant and humiliating...
# 24995   3453_3          0  It seems like more consideration has gone into...
# 24996   5064_1          0  I don't believe they made this film. Completel...
# 24997  10905_3          0  Guy is a loser. Can't get girls, needs to buil...
# 24998  10194_3          0  This 30 minute documentary BuÃ±uel made in the...
# 24999   8478_8          1  I saw this movie as a child and it broke my he...
#
# [25000 rows x 3 columns]

# %%
df[df['id'].str.contains('5814')]
# Out:
#            id  sentiment                                             review
# 0      5814_8          1  With all this stuff going down at the moment w...
# 14409  5814_3          0  The film did what it set out to do: show how a...

# %% [markdown]
# ## 2. Preprocessing

# %%
# stop words
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Removing special characters and "trash"
import re
def preprocessor(text):
    # Remove HTML markup
    # Remove HTML markup
    text = re.sub('<[^>]*>', '', text)
    # Save emoticons for later appending
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)', text)
    # Remove any non-word character and append the emoticons,
    # removing the nose character for standarization. Convert to lower case
    text = (re.sub('[\W]+', ' ', text.lower()) + ' ' + ' '.join(emoticons).replace('-', ''))
    # Your code here
    
    return text

# %%
# tokenizer and stemming
# tokenizer: to break down our twits in individual words
# stemming: reducing a word to its root
from nltk.stem import PorterStemmer
# Your code here
porter = PorterStemmer()

def tokenizer_porter(text):
    return [porter.stem(word) for word in text.split()]
     # Your code here

# %%
# split the dataset in train and test
# Your code here
from sklearn.model_selection import train_test_split
X = df.review
y = df.sentiment
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, stratify = df.sentiment)

# %%
X_train
# Out:
# 22887    Brian Dennehy, Bill Paxton, Joe Pantalino and,...
# 10058    Geniuses William Cameron Menzies and Herbert G...
# 23079    This modern film noir with its off beat humour...
# 17398    After not having much luck at selling his scre...
# 14335    I don't know what you guys are inhaling, but p...
# 15021    it's movies like these that make you wish that...
# 541      Meaning: if this movie got pitched, scripted, ...
# 479      CAROL'S JOURNEY is a pleasure to watch for so ...
# 12835    The Godfather Part I was a stunning look insid...
# 19696    This is one of my two or three favorite Stooge...
# 5844     Loved this show...smart acting, smart dialog, ...
# 13261    In many ways DIRTY WORK is a predictable L&H s...
# 14127    Clint Eastwood would star again as the battle-...
# 5169     The original \Vanishing Point\" was a great fl...
# 5191     I can see where the film makers were going wit...
# 121      Yes, I am just going to tell you about this on...
# 23628    I created my own reality by walking out of the...
# 7629     I was in a bad frame of mind when I first saw ...
# 5749     The premise of an African-American female Scro...
# 1919     Way to go ace! You just made a chilling, gross...
# 19259    I rented this movie, thinking it looked like a...
# 12514    If you go see this movie you'll be holding a g...
# 18786    \Her Cardboard Lover\" is Norma Shearer's last...
# 7956     Time For A Hit!<br /><br />Waqt Dir- Vipul Amr...
# 155      I don't usually comment, but there are things ...
# 8424     When I was born, this television series was th...
# 15765    Identical twin sisters Mary-Kate and Ashley Ol...
# 8673     \Smokey And The Bandit\" wasn't exactly Shakes...
# 1808     I saw this series when I was a kid and loved t...
# 13186    This piece of crap might have been acclaimed 6...
#                                ...
# 3233     I saw this movie with my friend and we couldnt...
# 8599     Some illegal so-called asylum seeker comes to ...
# 5299     If it wasn't for the performances of Barry Dia...
# 21641    and laugh out loud funny in many scenes.<br />...
# 6998     This is the best made-for-TV movie of all-time...
# 12182    \You're not going to shoot those little creatu...
# 5900     James Stewart stars in a classic western tale ...
# 654      Sandra Bernhard is quite a character, and cert...
# 11854    \Pandora's Clock\" is a gripping suspense/thri...
# 21556    It's not quite the timeless masterpiece you wo...
# 16026    Ever since seeing this film as a child, over 3...
# 16952    This is a beautiful movie that is wonderfully ...
# 24781    This film was so amateurish I could hardly bel...
# 3916     As I am from Hungary I have heard many people ...
# 712      Over the years, we've seen a lot of prepostero...
# 20831    Nicely done, and along with \New voyages\" it'...
# 21007    Zero Day leads you to think, even re-think why...
# 10178    This must have been one of the worst movies I ...
# 18341    If you like \Othello,\" you'll love this flick...
# 18672    A really great movie and true story. Dan Janse...
# 13511    Bored Londoners Henry Kendall and Joan Barry (...
# 21761    ... so I thought I'd throw in a few words abou...
# 21647    Batman: Mystery of the Batwoman is the latest ...
# 24484    This really doesn't do the blues justice. It s...
# 17092    The Class is a comedy series that portrays a b...
# 5720     IÂ´m not surprised that even cowgirls get the ...
# 4152     The final pairing of Nelson Eddy and Jeanette ...
# 7493     I really don't want to compare Martin Scorsese...
# 7595     How can there be that many corrupt cops withou...
# 4860     The most ridiculous thing about this ridiculou...
# Name: review, Length: 20000, dtype: object

# %% [markdown]
# ## 3. Create Model and Train
#
# Using **Pipeline** to concat **tfidf** step and **LogisticRegression** step

# %%
# Import Pipeline, LogisticRegression, TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words = stop, tokenizer=tokenizer_porter, preprocessor=preprocessor)
# Your code here

clf = Pipeline([('vect', tfidf),('clf', LogisticRegression(random_state=0))])
# Your code here)
clf.fit(X_train, y_train)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'ani', 'becaus', 'befor', 'doe', 'dure', 'ha', 'hi', 'onc', 'onli', 'ourselv', 'themselv', 'thi', 'veri', 'wa', 'whi', 'yourselv'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# D:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Pipeline(memory=None,
#          steps=[('vect',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 1), norm='l2',
#                                  preprocessor=<function preprocessor at 0x00000206AF465268>,
#                                  smooth_idf=True,
#                                  stop_words=['i', 'me', 'my', 'mysel...
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_porter at 0x00000206AE9F0D90>,
#                                  use_idf=True, vocabulary=None)),
#                 ('clf',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='warn', n_jobs=None,
#                                     penalty='l2', random_state=0, solver='warn',
#                                     tol=0.0001, verbose=0, warm_start=False))],
#          verbose=False)

# %% [markdown]
# ## 4. Evaluate Model

# %%
# Using Test dataset to evaluate model
# classification_report
# confusion matrix
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.89      2500
#            1       0.88      0.91      0.89      2500
#
#     accuracy                           0.89      5000
#    macro avg       0.89      0.89      0.89      5000
# weighted avg       0.89      0.89      0.89      5000
# array([[2177,  323],
#        [ 231, 2269]], dtype=int64)

# %% [markdown]
# ## 5. Export Model

# %%
# Using pickle to export our trained model
import pickle
import os

# %%
pickle.dump(clf, open(os.path.join('week3_lab', 'week3_lab', 'data','logisticRegression.pkl'), 'wb'), protocol=4)
